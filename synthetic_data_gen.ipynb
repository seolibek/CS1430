# %% [markdown]
# Data from UTKFACE cropped and aligned. See the following link: https://www.kaggle.com/datasets/moritzm00/utkface-cropped/data.
#
# We select 2000 photos, but in the preprocessing.py, i believe this ends up being 1717 total photos. the data is in

# %%
# Clone the SAM repository
# !git clone https://github.com/yuval-alaluf/SAM.git
# %cd SAM

# Install PyTorch and torchvision with CUDA
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118

# !pip install ninja
# Out:
# Cloning into 'SAM'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 228 (delta 32), reused 22 (delta 22), pack-reused 180 (from 1)
# Receiving objects: 100% (228/228), 24.63 MiB | 42.97 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# /content/SAM
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Here

# %%
import os
data_path = '/content/drive/My Drive/data'
files = os.listdir(data_path)
print("Files in the folder:", files)
print(data_path)
# Out:
# Files in the folder: ['40_1_1_20170112231359349.jpg.chip.jpg', '42_1_0_20170117163607667.jpg.chip.jpg', '42_0_2_20170112192934683.jpg.chip.jpg', '42_0_1_20170113175751788.jpg.chip.jpg', '42_1_4_20170109002558079.jpg.chip.jpg', '44_0_0_20170117135644544.jpg.chip.jpg', '42_0_2_20170104184350086.jpg.chip.jpg', '43_1_2_20170116162034067.jpg.chip.jpg', '42_0_1_20170116194444692.jpg.chip.jpg', '41_1_1_20170117194317075.jpg.chip.jpg', '43_0_0_20170117185833850.jpg.chip.jpg', '41_0_2_20170116192512743.jpg.chip.jpg', '42_1_4_20170103225757192.jpg.chip.jpg', '44_0_3_20170119162912596.jpg.chip.jpg', '40_0_2_20170116191940772.jpg.chip.jpg', '40_1_2_20170116191703413.jpg.chip.jpg', '42_0_0_20170116232941954.jpg.chip.jpg', '42_0_1_20170113190548728.jpg.chip.jpg', '43_0_3_20170112220309502.jpg.chip.jpg', '40_0_2_20170116191415693.jpg.chip.jpg', '40_1_2_20170109003053046.jpg.chip.jpg', '41_1_1_20170117171024861.jpg.chip.jpg', '43_1_4_20170117174415686.jpg.chip.jpg', '44_0_1_20170117142003663.jpg.chi
# ...

# %%
# !wget https://github.com/yuval-alaluf/SAM/releases/download/pretrained/sam_ffhq_aging.pt -P checkpoints/
# Out:
# --2024-12-06 16:11:48--  https://github.com/yuval-alaluf/SAM/releases/download/pretrained/sam_ffhq_aging.pt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-12-06 16:11:48 ERROR 404: Not Found.

# %%
# %cd SAM
# Out:
# [Errno 2] No such file or directory: 'SAM'
# /content/SAM

# %% [markdown]
# !pip install scipy matplotlib tqdm numpy opencv-python pillow tensorboard torch torchvision ninja

# %%
# !mkdir pretrained_models
# !pip install gdown
# !gdown "https://drive.google.com/uc?id=1XyumF6_fdAxFmxpFcmPf-q84LU_22EMC&export=download" -O pretrained_models/sam_ffhq_aging.pt

# !wget "https://github.com/italojs/facial-landmarks-recognition/blob/master/shape_predictor_68_face_landmarks.dat"
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1XyumF6_fdAxFmxpFcmPf-q84LU_22EMC&export=download
# From (redirected): https://drive.google.com/uc?id=1XyumF6_fdAxFmxpFcmPf-q84LU_22EMC&export=download&confirm=t&uuid=342117f0-11bd-4e71-994d-95a1bfd35c03
# To: /content/SAM/pretrained_models/sam_ffhq_aging.pt
# 100% 2.27G/2.27G [00:22<00:00, 101MB/s]
# --2024-12-06 16:24:47--  https://github.com/italojs/facial-landmarks-recognition/blob/master/shape_predictor_68_face_landmarks.dat
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘shape_predictor_68_face_landmarks.dat’
#
# shape_predictor_68_     [ <=>                ] 287.12K  --.-KB/s    in 0.1s
#
# 2024-12-06 16:24:48 (2.32 MB/s) - ‘shape_predictor_68_face_landmarks.dat’ saved [294011]

# %%
# !python scripts/inference.py \
--exp_dir=/content/SAM/results \
--checkpoint_path=/content/SAM/pretrained_models/sam_ffhq_aging.pt \
--data_path=/content/drive/MyDrive/data \
--test_batch_size=4 \
--test_workers=4 \
--couple_outputs \
--target_age=0,10,20,30,40,50,60,70,80
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# ...

# %%
# %ls -R ./inference_results
# %ls -R ./results
# Out:
# ls: cannot access './inference_results': No such file or directory
# ls: cannot access './results': No such file or directory

# %%
# !cp -r /content/SAM/results/inference_results /content/drive/My\ Drive/
# !cp -r /content/SAM/results/inference_coupled /content/drive/My\ Drive/

# %%
# !zip -r inference_results.zip /content/SAM/results/inference_results
# !zip -r inference_coupled.zip /content/SAM/results/inference_coupled
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/SAM/results/inference_coupled/50/35_0_3_20170117135015886.jpg.chip.jpg (deflated 3%)
#   adding: content/SAM/results/inference_coupled/50/58_0_0_20170117191927955.jpg.chip.jpg (deflated 6%)
#   adding: content/SAM/results/inference_coupled/50/40_1_4_20170117200930685.jpg.chip.jpg (deflated 7%)
#   adding: content/SAM/results/inference_coupled/50/26_1_1_20170116024044126.jpg.chip.jpg (deflated 4%)
#   adding: content/SAM/results/inference_coupled/50/61_0_3_20170119211813409.jpg.chip.jpg (deflated 4%)
#   adding: content/SAM/results/inference_coupled/50/40_0_4_20170104210123901.jpg.chip.jpg (deflated 3%)
#   adding: content/SAM/results/inference_coupled/50/67_0_0_20170104200734185.jpg.chip.jpg (deflated 5%)
#   adding: content/SAM/results/inference_coupled/50/75_0_0_20170117191812939.jpg.chip.jpg (deflated 2%)
#   adding: content/SAM/results/inference_coupled/50/67_0_1_20170120223307141.jpg.chip.jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download('/content/SAM/inference_results.zip')  # Change to your zip file path
files.download('/content/SAM/inference_coupled.zip') # Change to your zip file path

# %% [markdown]
# todo potentially: change the names of the files because the datetime step is completely useless for us
